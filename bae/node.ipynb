# %%
class State(MessagesState):


def parsing_node():
    """
    사용자에게 입력받은 메시지를 파싱하고 의도를 분석합니다.
    """
    return

def memo_check_node():
    """
    기존 사용자의 메모를 확인하고 컨텍스트를 로드합니다.
    """
    return

# def recommendation_node():
#     """
#     """
#     pass

def tool_execution_node():
    """
    어떤 툴을 호출하고 실행할지 결정합니다
    """
    return

def general_response_node():
    """
    웨딩과 관련없는 메세지가 들어오면 일반적인 대화를 생성해서 응답합니다.
    """
    return    

def memo_update_node():
    """
    대화 내용을 메모에 업데이트합니다.
    """
    return 

def response_generation_node():
    """
    사용자의 메모를 참고하여 최종응답을 생성합니다.
    """
    return 

def error_handler_node():
    """
    각종 에러를 처리하고 복구 로직을 만듭니다.
    """
    return
